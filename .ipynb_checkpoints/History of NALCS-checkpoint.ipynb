# %%
import pandas as pd
import numpy as np
import datetime

history = pd.read_excel("Test.xlsx")
history.head(7)
# Out:
#          Date Patch                  Blue                   Red  \
# 0  2013-04-20     -           Team Vulcun            Team Curse
# 1  2013-04-20     -     compLexity Gaming              Team MRN
# 2  2013-04-20     -         Team Dignitas          Team SoloMid
# 3  2013-04-20     -  Good Game University  Counter Logic Gaming
# 4  2013-04-19     -         Team Dignitas           Team Vulcun
# 5  2013-04-19     -          Team SoloMid  Good Game University
# 6  2013-04-19     -            Team Curse     compLexity Gaming
#
#                  Winner                 Loser  \
# 0           Team Vulcun            Team Curse
# 1              Team MRN     compLexity Gaming
# 2          Team SoloMid         Team Dignitas
# 3  Good Game University  Counter Logic Gaming
# 4           Team Vulcun         Team Dignitas
# 5          Team SoloMid  Good Game University
# 6     compLexity Gaming            Team Curse
#
#                           Blue_Bans                     Red_Bans  \
# ...

# %%
def no_k(gold):
    if gold == 'k' or gold == '-':
        gold = np.nan
    else:
        gold = float(gold[:-1])*1000
    return gold
def no_dash(item):
    if item == '-':
        item = np.nan
    return item

for name in ['Blue_Gold','Red_Gold','Diff_Gold']:
    history[name] = history[name].apply(no_k)
    
for name in ['Patch','Diff_Kills', 'Diff_Towers', 'Diff_Dragons', 'Diff_Barons', 'Diff_RiftHerald']:
    history[name] = history[name].apply(no_dash)
    
    
main_history = history[['Date', 'Patch','Blue','Red','Winner','Loser', 'Tournament']]    
cloud9 = main_history[(main_history['Blue']=='Cloud9') | (main_history['Red'] == 'Cloud9')]

# %%
cloud9 = cloud9.sort_values(by=['Date']).reset_index(drop=True)
cloud9.head(5)
# Out:
#          Date Patch              Blue         Red  Winner             Loser  \
# 0  2013-06-12   NaN     Team Dignitas      Cloud9  Cloud9     Team Dignitas
# 1  2013-06-13   NaN      Team SoloMid      Cloud9  Cloud9      Team SoloMid
# 2  2013-06-13   NaN            Cloud9  Team Curse  Cloud9        Team Curse
# 3  2013-06-14   NaN            Cloud9  Team Coast  Cloud9        Team Coast
# 4  2013-06-15   NaN  Velocity eSports      Cloud9  Cloud9  Velocity eSports
#
#            Tournament
# 0  NA-LCS-2013-Summer
# 1  NA-LCS-2013-Summer
# 2  NA-LCS-2013-Summer
# 3  NA-LCS-2013-Summer
# 4  NA-LCS-2013-Summer

# %%
all_teams = list(history['Blue'].unique())
all_elo = {}
for i in all_teams:
    elo = {
        date=
    }
# Out:
# ['Team Vulcun', 'compLexity Gaming', 'Team Dignitas', 'Good Game University', 'Team SoloMid', 'Team Curse', 'Team MRN', 'Counter Logic Gaming', 'Cloud9', 'Team Coast', 'Velocity eSports', 'Azure Cats', 'Team Summon', 'Quantic Gaming', 'DoubleBuff', 'Fidelis', 'The Salad Bar', 'Team Astral Poke', 'COGnitive Gaming', 'vVv Gaming', 'Curse Academy', 'Napkins in Disguise', 'Team VEX', 'Gold Gaming LA', 'Denial eSports.East', 'New World Eclipse', 'To Be Determined', 'The Walking Zed', 'Evil Geniuses', 'Team EnVyUs', 'Team Liquid', 'Big Gods Jackals', 'Echo Fox', 'Phoenix1', 'LMQ', 'Team 8', 'FlyQuest', 'Renegades', 'Gold Coin United', 'XDG Gaming', 'Immortals', 'Team Infernal Drake (NASG Team)', 'Team Confound', 'Cloud9 Tempest', 'eUnited', 'Team Imagine', 'Enemy', 'Delta Fox', 'Team Gates', 'Tempo Storm', 'Apex Gaming', 'Final Five', 'Gravity', 'Nova eSports', 'Dream Team', 'Team Liquid Academy', 'Team Dragon Knights', 'NRG Esports', 'Apex Pride', 'Monster Kittens', 'Misfits (North Americ
# ...
